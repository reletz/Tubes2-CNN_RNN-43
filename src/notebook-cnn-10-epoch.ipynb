# %% [markdown]
# # Eksperimen CNN

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"] = "1"
import sys
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
import time
import shutil

sys.path.append("/kaggle/input/datasets/andifarhan01/code-tubes-2-ml")

from src.nn.models.cnn_model import CNNClassifier, ConvBlockSpec
from src.utils.gradcam import overlay_heatmap

DATASET_PATH = "/kaggle/input/datasets/puneet6060/intel-image-classification/seg_train/seg_train"
TEST_DATASET_PATH = "/kaggle/input/datasets/puneet6060/intel-image-classification/seg_test/seg_test"
IMG_SIZE = (64, 64)
BATCH_SIZE = 32
NUM_CLASSES = 6
MODEL_INPUT_DIR = "/kaggle/working/models"

# %% [markdown]
# ## 1. Data Loading

# %%
from pathlib import Path
import random
from src.utils.image_utils import load_batch

def get_paths_and_labels(dataset_path):
    dpath = Path(dataset_path)
    classes = sorted([d.name for d in dpath.iterdir() if d.is_dir()])
    class_to_idx = {c: i for i, c in enumerate(classes)}
    paths, labels = [], []
    for c in classes:
        for f in (dpath / c).glob('*.jpg'):
            paths.append(str(f))
            labels.append(class_to_idx[c])
    return paths, labels, classes

paths_all, labels_all, class_names = get_paths_and_labels(DATASET_PATH)

# Shuffle & Split 80:20 (Train/Val)
combined = list(zip(paths_all, labels_all))
random.seed(123)
random.shuffle(combined)
paths_all, labels_all = zip(*combined)

split_idx = int(0.8 * len(paths_all))
train_paths, train_labels = paths_all[:split_idx], labels_all[:split_idx]
val_paths, val_labels = paths_all[split_idx:], labels_all[split_idx:]

test_paths, test_labels, _ = get_paths_and_labels(TEST_DATASET_PATH)

def make_tf_dataset(paths, labels, batch_size, shuffle=True):
    paths_list = list(paths)
    labels_list = list(labels)
    ds = tf.data.Dataset.from_tensor_slices((paths_list, labels_list))
    if shuffle:
        ds = ds.shuffle(buffer_size=len(paths_list), reshuffle_each_iteration=True)
    
    ds = ds.batch(batch_size)
    
    def process_batch(paths_tensor, labels_tensor):
        def _load_batch_wrapper(paths_bytes):
            paths_str = [p.decode('utf-8') for p in paths_bytes]
            images = load_batch(paths_str, IMG_SIZE)
            return images.astype(np.float32)
            
        images_tensor = tf.numpy_function(_load_batch_wrapper, [paths_tensor], tf.float32)
        images_tensor.set_shape((None, IMG_SIZE[0], IMG_SIZE[1], 3))
        return images_tensor, labels_tensor
        
    ds = ds.map(process_batch, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds

train_ds = make_tf_dataset(train_paths, train_labels, BATCH_SIZE, shuffle=True)
val_ds = make_tf_dataset(val_paths, val_labels, BATCH_SIZE, shuffle=False)
test_ds = make_tf_dataset(test_paths, test_labels, BATCH_SIZE, shuffle=False)

train_steps = (len(train_paths) + BATCH_SIZE - 1) // BATCH_SIZE
val_steps = (len(val_paths) + BATCH_SIZE - 1) // BATCH_SIZE
print(f"Train: {len(train_paths)} images ({train_steps} steps), Val: {len(val_paths)} images ({val_steps} steps), Test: {len(test_paths)} images")
# Out:
# Train: 11227 images (351 steps), Val: 2807 images (88 steps), Test: 3000 images

# %% [markdown]
# ## 2. Keras Model Builder & Training 16 Variasi (Pengaruh Hyperparameter)

# %%
def build_keras_cnn(num_layers, filters_list, kernel_sizes, pool_type):
    inputs = keras.Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
    x = inputs
    for i in range(num_layers):
        x = layers.Conv2D(filters_list[i], kernel_sizes[i], padding="same", activation="relu")(x)
        if pool_type == "max":
            x = layers.MaxPooling2D(pool_size=(2, 2))(x)
        else:
            x = layers.AveragePooling2D(pool_size=(2, 2))(x)
    x = layers.Flatten()(x)
    outputs = layers.Dense(NUM_CLASSES, activation="softmax")(x)
    model = keras.Model(inputs, outputs)
    model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    return model

variations = []
for num_layers in [2, 3]:
    for filters in [[16, 32, 64], [32, 64, 128]]:
        for kernels in [[(3,3)]*3, [(5,5)]*3]:
            for pool in ["max", "avg"]:
                variations.append((num_layers, filters[:num_layers], kernels[:num_layers], pool))

print(f"Total Variations: {len(variations)}")
# Out:
# Total Variations: 16

# %%
# Fungsi evaluasi F1-Score pada Test Dataset (Keras)
def evaluate_f1(model, dataset):
    y_true = []
    y_pred = []
    for X_batch, y_batch in dataset:
        preds = model.predict(X_batch, verbose=0)
        y_true.extend(y_batch.numpy())
        y_pred.extend(np.argmax(preds, axis=1))
    return f1_score(y_true, y_pred, average='macro')

history_dict = {}
evaluation_results = {}
os.makedirs("models", exist_ok=True)

# Loop 16 variasi
for i, (nl, fl, ks, pt) in enumerate(variations):
    print(f"--- Training Variation {i+1}/16: Layers={nl}, Filters={fl}, Kernels={ks}, Pool={pt} ---")
    model = build_keras_cnn(nl, fl, ks, pt)
    
    history = model.fit(train_ds.repeat(), steps_per_epoch=train_steps, 
                        validation_data=val_ds.repeat(), validation_steps=val_steps, 
                        epochs=10, verbose=1) 
    
    # Save weights
    weight_path = f"models/cnn_var_{i}.weights.h5"
    if os.path.exists(weight_path):
        os.remove(weight_path)
    model.save_weights(weight_path)
    history_dict[i] = history.history
    
    # Evaluasi Macro F1-Score pada Test Set sesuai spesifikasi
    f1 = evaluate_f1(model, test_ds)
    evaluation_results[i] = {"f1_score": f1, "config": (nl, fl, ks, pt)}
    print(f"Keras Test Macro F1-Score: {f1:.4f}")
# Out:
# --- Training Variation 1/16: Layers=2, Filters=[16, 32], Kernels=[(3, 3), (3, 3)], Pool=max ---
# Epoch 1/10
# 351/351 [==============================] - 14s 36ms/step - loss: 1.1056 - accuracy: 0.5816 - val_loss: 0.8556 - val_accuracy: 0.6804
# Epoch 2/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.8160 - accuracy: 0.7021 - val_loss: 0.8259 - val_accuracy: 0.6975
# Epoch 3/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.7256 - accuracy: 0.7388 - val_loss: 0.8092 - val_accuracy: 0.6940
# Epoch 4/10
# 351/351 [==============================] - 12s 34ms/step - loss: 0.6636 - accuracy: 0.7625 - val_loss: 0.7387 - val_accuracy: 0.7300
# Epoch 5/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.5932 - accuracy: 0.7926 - val_loss: 0.7225 - val_accuracy: 0.7481
# Epoch 6/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5445 - accuracy: 0.8086 - val_loss: 0.6741 - val_accuracy: 0.7624
# Epoch 7/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.4934 - accuracy: 0.8266 - val_loss: 0.7475 - val_accuracy: 0.7353
# Epoch 8/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.4447 - accuracy: 0.8431 - val_loss: 0.7482 - val_accuracy: 0.7257
# Epoch 9/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.4055 - accuracy: 0.8602 - val_loss: 0.7265 - val_accuracy: 0.7417
# Epoch 10/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3788 - accuracy: 0.8713 - val_loss: 0.7377 - val_accuracy: 0.7535
# Keras Test Macro F1-Score: 0.7651
# --- Training Variation 2/16: Layers=2, Filters=[16, 32], Kernels=[(3, 3), (3, 3)], Pool=avg ---
# Epoch 1/10
# 351/351 [==============================] - 11s 27ms/step - loss: 1.1578 - accuracy: 0.5622 - val_loss: 0.9934 - val_accuracy: 0.6231
# Epoch 2/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.8979 - accuracy: 0.6694 - val_loss: 0.9278 - val_accuracy: 0.6527
# Epoch 3/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.8066 - accuracy: 0.7051 - val_loss: 0.8158 - val_accuracy: 0.6926
# Epoch 4/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.7614 - accuracy: 0.7217 - val_loss: 0.8180 - val_accuracy: 0.6958
# Epoch 5/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.7303 - accuracy: 0.7298 - val_loss: 0.8251 - val_accuracy: 0.6922
# Epoch 6/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.6782 - accuracy: 0.7565 - val_loss: 0.7916 - val_accuracy: 0.7093
# Epoch 7/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.6500 - accuracy: 0.7649 - val_loss: 0.8110 - val_accuracy: 0.7004
# Epoch 8/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.6085 - accuracy: 0.7804 - val_loss: 0.7894 - val_accuracy: 0.7093
# Epoch 9/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.5860 - accuracy: 0.7926 - val_loss: 0.7818 - val_accuracy: 0.7193
# Epoch 10/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5496 - accuracy: 0.8087 - val_loss: 0.7419 - val_accuracy: 0.7424
# Keras Test Macro F1-Score: 0.7473
# --- Training Variation 3/16: Layers=2, Filters=[16, 32], Kernels=[(5, 5), (5, 5)], Pool=max ---
# Epoch 1/10
# 351/351 [==============================] - 11s 28ms/step - loss: 1.0775 - accuracy: 0.5871 - val_loss: 0.9189 - val_accuracy: 0.6448
# Epoch 2/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.8127 - accuracy: 0.6997 - val_loss: 0.7724 - val_accuracy: 0.7107
# Epoch 3/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.7056 - accuracy: 0.7496 - val_loss: 0.7794 - val_accuracy: 0.7064
# Epoch 4/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.6145 - accuracy: 0.7819 - val_loss: 0.7375 - val_accuracy: 0.7378
# Epoch 5/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.5331 - accuracy: 0.8121 - val_loss: 0.7365 - val_accuracy: 0.7474
# Epoch 6/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.4689 - accuracy: 0.8367 - val_loss: 0.7178 - val_accuracy: 0.7481
# Epoch 7/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.4169 - accuracy: 0.8543 - val_loss: 0.7516 - val_accuracy: 0.7517
# Epoch 8/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.3724 - accuracy: 0.8709 - val_loss: 0.8263 - val_accuracy: 0.7332
# Epoch 9/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.3236 - accuracy: 0.8868 - val_loss: 0.7676 - val_accuracy: 0.7528
# Epoch 10/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.2833 - accuracy: 0.9041 - val_loss: 0.7968 - val_accuracy: 0.7563
# Keras Test Macro F1-Score: 0.7639
# --- Training Variation 4/16: Layers=2, Filters=[16, 32], Kernels=[(5, 5), (5, 5)], Pool=avg ---
# Epoch 1/10
# 351/351 [==============================] - 11s 26ms/step - loss: 1.0965 - accuracy: 0.5803 - val_loss: 0.9299 - val_accuracy: 0.6452
# Epoch 2/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.8656 - accuracy: 0.6835 - val_loss: 0.8687 - val_accuracy: 0.6790
# Epoch 3/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.7733 - accuracy: 0.7178 - val_loss: 0.8194 - val_accuracy: 0.7104
# Epoch 4/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.7020 - accuracy: 0.7432 - val_loss: 0.7890 - val_accuracy: 0.7200
# Epoch 5/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.6346 - accuracy: 0.7756 - val_loss: 0.7784 - val_accuracy: 0.7260
# Epoch 6/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.5930 - accuracy: 0.7860 - val_loss: 0.7619 - val_accuracy: 0.7439
# Epoch 7/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5516 - accuracy: 0.7989 - val_loss: 0.7691 - val_accuracy: 0.7428
# Epoch 8/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.4999 - accuracy: 0.8220 - val_loss: 0.7885 - val_accuracy: 0.7303
# Epoch 9/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.4629 - accuracy: 0.8318 - val_loss: 0.8126 - val_accuracy: 0.7250
# Epoch 10/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.4222 - accuracy: 0.8510 - val_loss: 0.7540 - val_accuracy: 0.7542
# Keras Test Macro F1-Score: 0.7508
# --- Training Variation 5/16: Layers=2, Filters=[32, 64], Kernels=[(3, 3), (3, 3)], Pool=max ---
# Epoch 1/10
# 351/351 [==============================] - 11s 26ms/step - loss: 1.0193 - accuracy: 0.6187 - val_loss: 0.8773 - val_accuracy: 0.6690
# Epoch 2/10
# 351/351 [==============================] - 9s 26ms/step - loss: 0.7413 - accuracy: 0.7331 - val_loss: 0.7890 - val_accuracy: 0.7004
# Epoch 3/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.6402 - accuracy: 0.7701 - val_loss: 0.7028 - val_accuracy: 0.7435
# Epoch 4/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.5280 - accuracy: 0.8157 - val_loss: 0.7023 - val_accuracy: 0.7467
# Epoch 5/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.4518 - accuracy: 0.8404 - val_loss: 0.7103 - val_accuracy: 0.7577
# Epoch 6/10
# 351/351 [==============================] - 11s 32ms/step - loss: 0.3787 - accuracy: 0.8685 - val_loss: 0.8065 - val_accuracy: 0.7399
# Epoch 7/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3287 - accuracy: 0.8855 - val_loss: 0.7128 - val_accuracy: 0.7574
# Epoch 8/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.2704 - accuracy: 0.9097 - val_loss: 0.8371 - val_accuracy: 0.7382
# Epoch 9/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.2189 - accuracy: 0.9277 - val_loss: 0.8331 - val_accuracy: 0.7602
# Epoch 10/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.1788 - accuracy: 0.9423 - val_loss: 0.8545 - val_accuracy: 0.7681
# Keras Test Macro F1-Score: 0.7749
# --- Training Variation 6/16: Layers=2, Filters=[32, 64], Kernels=[(3, 3), (3, 3)], Pool=avg ---
# Epoch 1/10
# 351/351 [==============================] - 12s 30ms/step - loss: 1.1188 - accuracy: 0.5709 - val_loss: 0.9517 - val_accuracy: 0.6470
# Epoch 2/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.8493 - accuracy: 0.6874 - val_loss: 0.9124 - val_accuracy: 0.6683
# Epoch 3/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.7759 - accuracy: 0.7105 - val_loss: 0.8185 - val_accuracy: 0.7047
# Epoch 4/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.6862 - accuracy: 0.7520 - val_loss: 0.7856 - val_accuracy: 0.7036
# Epoch 5/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.6311 - accuracy: 0.7702 - val_loss: 0.7445 - val_accuracy: 0.7264
# Epoch 6/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.5658 - accuracy: 0.7986 - val_loss: 0.7512 - val_accuracy: 0.7353
# Epoch 7/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.5245 - accuracy: 0.8172 - val_loss: 0.7269 - val_accuracy: 0.7481
# Epoch 8/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.4618 - accuracy: 0.8364 - val_loss: 0.7011 - val_accuracy: 0.7577
# Epoch 9/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.4182 - accuracy: 0.8536 - val_loss: 0.7408 - val_accuracy: 0.7496
# Epoch 10/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3785 - accuracy: 0.8681 - val_loss: 0.7581 - val_accuracy: 0.7553
# Keras Test Macro F1-Score: 0.7695
# --- Training Variation 7/16: Layers=2, Filters=[32, 64], Kernels=[(5, 5), (5, 5)], Pool=max ---
# Epoch 1/10
# 351/351 [==============================] - 11s 28ms/step - loss: 1.0495 - accuracy: 0.6006 - val_loss: 0.9048 - val_accuracy: 0.6441
# Epoch 2/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.8053 - accuracy: 0.7046 - val_loss: 0.7656 - val_accuracy: 0.7114
# Epoch 3/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.6511 - accuracy: 0.7637 - val_loss: 0.7123 - val_accuracy: 0.7449
# Epoch 4/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.5592 - accuracy: 0.8057 - val_loss: 0.7170 - val_accuracy: 0.7531
# Epoch 5/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.4669 - accuracy: 0.8386 - val_loss: 0.6997 - val_accuracy: 0.7659
# Epoch 6/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3997 - accuracy: 0.8609 - val_loss: 0.7877 - val_accuracy: 0.7417
# Epoch 7/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3353 - accuracy: 0.8859 - val_loss: 0.7974 - val_accuracy: 0.7410
# Epoch 8/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.2777 - accuracy: 0.9058 - val_loss: 0.8713 - val_accuracy: 0.7307
# Epoch 9/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.2165 - accuracy: 0.9296 - val_loss: 0.8950 - val_accuracy: 0.7520
# Epoch 10/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.1759 - accuracy: 0.9440 - val_loss: 0.9355 - val_accuracy: 0.7563
# Keras Test Macro F1-Score: 0.7434
# --- Training Variation 8/16: Layers=2, Filters=[32, 64], Kernels=[(5, 5), (5, 5)], Pool=avg ---
# Epoch 1/10
# 351/351 [==============================] - 11s 27ms/step - loss: 1.1115 - accuracy: 0.5711 - val_loss: 0.9778 - val_accuracy: 0.6295
# Epoch 2/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.8827 - accuracy: 0.6757 - val_loss: 0.9122 - val_accuracy: 0.6487
# Epoch 3/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.7780 - accuracy: 0.7109 - val_loss: 0.8432 - val_accuracy: 0.6758
# Epoch 4/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.7053 - accuracy: 0.7423 - val_loss: 0.7531 - val_accuracy: 0.7339
# Epoch 5/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.6183 - accuracy: 0.7755 - val_loss: 0.7895 - val_accuracy: 0.7175
# Epoch 6/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.5917 - accuracy: 0.7840 - val_loss: 0.7929 - val_accuracy: 0.7232
# Epoch 7/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5179 - accuracy: 0.8165 - val_loss: 0.7465 - val_accuracy: 0.7460
# Epoch 8/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.4714 - accuracy: 0.8309 - val_loss: 0.8156 - val_accuracy: 0.7257
# Epoch 9/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.4347 - accuracy: 0.8450 - val_loss: 0.8324 - val_accuracy: 0.7235
# Epoch 10/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3918 - accuracy: 0.8609 - val_loss: 0.8207 - val_accuracy: 0.7257
# Keras Test Macro F1-Score: 0.7312
# --- Training Variation 9/16: Layers=3, Filters=[16, 32, 64], Kernels=[(3, 3), (3, 3), (3, 3)], Pool=max ---
# Epoch 1/10
# 351/351 [==============================] - 12s 29ms/step - loss: 1.0668 - accuracy: 0.5894 - val_loss: 0.9520 - val_accuracy: 0.6188
# Epoch 2/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.8178 - accuracy: 0.6976 - val_loss: 0.8101 - val_accuracy: 0.6975
# Epoch 3/10
# 351/351 [==============================] - 12s 35ms/step - loss: 0.7021 - accuracy: 0.7440 - val_loss: 0.7324 - val_accuracy: 0.7271
# Epoch 4/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.6347 - accuracy: 0.7750 - val_loss: 0.6345 - val_accuracy: 0.7716
# Epoch 5/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.5630 - accuracy: 0.7967 - val_loss: 0.6154 - val_accuracy: 0.7791
# Epoch 6/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5248 - accuracy: 0.8162 - val_loss: 0.6457 - val_accuracy: 0.7659
# Epoch 7/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.4821 - accuracy: 0.8300 - val_loss: 0.6278 - val_accuracy: 0.7805
# Epoch 8/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.4432 - accuracy: 0.8447 - val_loss: 0.6312 - val_accuracy: 0.7848
# Epoch 9/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.4119 - accuracy: 0.8573 - val_loss: 0.6139 - val_accuracy: 0.7859
# Epoch 10/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3815 - accuracy: 0.8656 - val_loss: 0.6060 - val_accuracy: 0.7866
# Keras Test Macro F1-Score: 0.7944
# --- Training Variation 10/16: Layers=3, Filters=[16, 32, 64], Kernels=[(3, 3), (3, 3), (3, 3)], Pool=avg ---
# Epoch 1/10
# 351/351 [==============================] - 11s 27ms/step - loss: 1.1522 - accuracy: 0.5586 - val_loss: 0.9130 - val_accuracy: 0.6498
# Epoch 2/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.8711 - accuracy: 0.6725 - val_loss: 0.8351 - val_accuracy: 0.6883
# Epoch 3/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.8008 - accuracy: 0.7054 - val_loss: 0.8278 - val_accuracy: 0.6911
# Epoch 4/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.7416 - accuracy: 0.7257 - val_loss: 0.7633 - val_accuracy: 0.7178
# Epoch 5/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.6998 - accuracy: 0.7429 - val_loss: 0.7260 - val_accuracy: 0.7310
# Epoch 6/10
# 351/351 [==============================] - 11s 31ms/step - loss: 0.6527 - accuracy: 0.7618 - val_loss: 0.7754 - val_accuracy: 0.7243
# Epoch 7/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.6089 - accuracy: 0.7799 - val_loss: 0.7072 - val_accuracy: 0.7428
# Epoch 8/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.5802 - accuracy: 0.7926 - val_loss: 0.6533 - val_accuracy: 0.7634
# Epoch 9/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.5489 - accuracy: 0.8050 - val_loss: 0.6430 - val_accuracy: 0.7620
# Epoch 10/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5326 - accuracy: 0.8101 - val_loss: 0.6378 - val_accuracy: 0.7645
# Keras Test Macro F1-Score: 0.7728
# --- Training Variation 11/16: Layers=3, Filters=[16, 32, 64], Kernels=[(5, 5), (5, 5), (5, 5)], Pool=max ---
# Epoch 1/10
# 351/351 [==============================] - 12s 29ms/step - loss: 1.1315 - accuracy: 0.5653 - val_loss: 0.8882 - val_accuracy: 0.6601
# Epoch 2/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.8405 - accuracy: 0.6842 - val_loss: 0.7720 - val_accuracy: 0.7228
# Epoch 3/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.7139 - accuracy: 0.7376 - val_loss: 0.7279 - val_accuracy: 0.7346
# Epoch 4/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.6237 - accuracy: 0.7787 - val_loss: 0.6764 - val_accuracy: 0.7627
# Epoch 5/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.5458 - accuracy: 0.8039 - val_loss: 0.6160 - val_accuracy: 0.7777
# Epoch 6/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.4834 - accuracy: 0.8309 - val_loss: 0.6094 - val_accuracy: 0.7827
# Epoch 7/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.4313 - accuracy: 0.8468 - val_loss: 0.6233 - val_accuracy: 0.7834
# Epoch 8/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3659 - accuracy: 0.8725 - val_loss: 0.6942 - val_accuracy: 0.7645
# Epoch 9/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3168 - accuracy: 0.8878 - val_loss: 0.7239 - val_accuracy: 0.7610
# Epoch 10/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.2688 - accuracy: 0.9053 - val_loss: 0.7228 - val_accuracy: 0.7713
# Keras Test Macro F1-Score: 0.7689
# --- Training Variation 12/16: Layers=3, Filters=[16, 32, 64], Kernels=[(5, 5), (5, 5), (5, 5)], Pool=avg ---
# Epoch 1/10
# 351/351 [==============================] - 11s 27ms/step - loss: 1.1307 - accuracy: 0.5517 - val_loss: 0.8932 - val_accuracy: 0.6530
# Epoch 2/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.8724 - accuracy: 0.6703 - val_loss: 0.8847 - val_accuracy: 0.6616
# Epoch 3/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.7534 - accuracy: 0.7192 - val_loss: 0.7902 - val_accuracy: 0.6968
# Epoch 4/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.7123 - accuracy: 0.7379 - val_loss: 0.7221 - val_accuracy: 0.7264
# Epoch 5/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.6332 - accuracy: 0.7684 - val_loss: 0.6722 - val_accuracy: 0.7496
# Epoch 6/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5949 - accuracy: 0.7813 - val_loss: 0.6413 - val_accuracy: 0.7716
# Epoch 7/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5548 - accuracy: 0.8021 - val_loss: 0.6187 - val_accuracy: 0.7709
# Epoch 8/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5324 - accuracy: 0.8106 - val_loss: 0.6976 - val_accuracy: 0.7567
# Epoch 9/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.4997 - accuracy: 0.8238 - val_loss: 0.6206 - val_accuracy: 0.7788
# Epoch 10/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.4735 - accuracy: 0.8304 - val_loss: 0.6177 - val_accuracy: 0.7766
# Keras Test Macro F1-Score: 0.7889
# --- Training Variation 13/16: Layers=3, Filters=[32, 64, 128], Kernels=[(3, 3), (3, 3), (3, 3)], Pool=max ---
# Epoch 1/10
# 351/351 [==============================] - 11s 27ms/step - loss: 1.0138 - accuracy: 0.6140 - val_loss: 0.8227 - val_accuracy: 0.6908
# Epoch 2/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.7416 - accuracy: 0.7299 - val_loss: 0.6951 - val_accuracy: 0.7556
# Epoch 3/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.6194 - accuracy: 0.7776 - val_loss: 0.6413 - val_accuracy: 0.7738
# Epoch 4/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.5404 - accuracy: 0.8056 - val_loss: 0.6951 - val_accuracy: 0.7399
# Epoch 5/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.4731 - accuracy: 0.8324 - val_loss: 0.6122 - val_accuracy: 0.7791
# Epoch 6/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.4207 - accuracy: 0.8487 - val_loss: 0.5901 - val_accuracy: 0.7891
# Epoch 7/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.3594 - accuracy: 0.8741 - val_loss: 0.6075 - val_accuracy: 0.7959
# Epoch 8/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3041 - accuracy: 0.8937 - val_loss: 0.6210 - val_accuracy: 0.7916
# Epoch 9/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.2605 - accuracy: 0.9090 - val_loss: 0.7191 - val_accuracy: 0.7838
# Epoch 10/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.2144 - accuracy: 0.9271 - val_loss: 0.6834 - val_accuracy: 0.7930
# Keras Test Macro F1-Score: 0.8039
# --- Training Variation 14/16: Layers=3, Filters=[32, 64, 128], Kernels=[(3, 3), (3, 3), (3, 3)], Pool=avg ---
# Epoch 1/10
# 351/351 [==============================] - 11s 28ms/step - loss: 1.1184 - accuracy: 0.5682 - val_loss: 0.9077 - val_accuracy: 0.6473
# Epoch 2/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.8347 - accuracy: 0.6868 - val_loss: 0.8131 - val_accuracy: 0.6840
# Epoch 3/10
# 351/351 [==============================] - 10s 27ms/step - loss: 0.7377 - accuracy: 0.7282 - val_loss: 0.7599 - val_accuracy: 0.7146
# Epoch 4/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.6484 - accuracy: 0.7635 - val_loss: 0.7634 - val_accuracy: 0.7068
# Epoch 5/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.5827 - accuracy: 0.7912 - val_loss: 0.6676 - val_accuracy: 0.7556
# Epoch 6/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.5429 - accuracy: 0.8054 - val_loss: 0.6567 - val_accuracy: 0.7656
# Epoch 7/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.5055 - accuracy: 0.8195 - val_loss: 0.6855 - val_accuracy: 0.7634
# Epoch 8/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.4831 - accuracy: 0.8280 - val_loss: 0.6441 - val_accuracy: 0.7802
# Epoch 9/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.4433 - accuracy: 0.8408 - val_loss: 0.6137 - val_accuracy: 0.7784
# Epoch 10/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.4135 - accuracy: 0.8540 - val_loss: 0.6165 - val_accuracy: 0.7902
# Keras Test Macro F1-Score: 0.8010
# --- Training Variation 15/16: Layers=3, Filters=[32, 64, 128], Kernels=[(5, 5), (5, 5), (5, 5)], Pool=max ---
# Epoch 1/10
# 351/351 [==============================] - 11s 28ms/step - loss: 1.0493 - accuracy: 0.5927 - val_loss: 0.8476 - val_accuracy: 0.6737
# Epoch 2/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.7718 - accuracy: 0.7170 - val_loss: 0.7395 - val_accuracy: 0.7278
# Epoch 3/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.6289 - accuracy: 0.7745 - val_loss: 0.6859 - val_accuracy: 0.7503
# Epoch 4/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.5478 - accuracy: 0.8047 - val_loss: 0.6589 - val_accuracy: 0.7688
# Epoch 5/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.4755 - accuracy: 0.8338 - val_loss: 0.6509 - val_accuracy: 0.7816
# Epoch 6/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3865 - accuracy: 0.8641 - val_loss: 0.6366 - val_accuracy: 0.7934
# Epoch 7/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3251 - accuracy: 0.8871 - val_loss: 0.6729 - val_accuracy: 0.7820
# Epoch 8/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.2583 - accuracy: 0.9113 - val_loss: 0.7545 - val_accuracy: 0.7777
# Epoch 9/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.1919 - accuracy: 0.9344 - val_loss: 0.8397 - val_accuracy: 0.7756
# Epoch 10/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.1507 - accuracy: 0.9503 - val_loss: 0.9515 - val_accuracy: 0.7332
# Keras Test Macro F1-Score: 0.7543
# --- Training Variation 16/16: Layers=3, Filters=[32, 64, 128], Kernels=[(5, 5), (5, 5), (5, 5)], Pool=avg ---
# Epoch 1/10
# 351/351 [==============================] - 11s 27ms/step - loss: 1.1457 - accuracy: 0.5520 - val_loss: 0.9588 - val_accuracy: 0.6327
# Epoch 2/10
# 351/351 [==============================] - 9s 27ms/step - loss: 0.8919 - accuracy: 0.6599 - val_loss: 0.8418 - val_accuracy: 0.6755
# Epoch 3/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.7810 - accuracy: 0.7072 - val_loss: 0.7815 - val_accuracy: 0.7097
# Epoch 4/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.6973 - accuracy: 0.7441 - val_loss: 0.6806 - val_accuracy: 0.7463
# Epoch 5/10
# 351/351 [==============================] - 11s 30ms/step - loss: 0.6242 - accuracy: 0.7700 - val_loss: 0.6946 - val_accuracy: 0.7485
# Epoch 6/10
# 351/351 [==============================] - 10s 30ms/step - loss: 0.5699 - accuracy: 0.7951 - val_loss: 0.7036 - val_accuracy: 0.7399
# Epoch 7/10
# 351/351 [==============================] - 10s 29ms/step - loss: 0.5057 - accuracy: 0.8180 - val_loss: 0.6684 - val_accuracy: 0.7627
# Epoch 8/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.4748 - accuracy: 0.8278 - val_loss: 0.6457 - val_accuracy: 0.7802
# Epoch 9/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.4165 - accuracy: 0.8518 - val_loss: 0.6470 - val_accuracy: 0.7784
# Epoch 10/10
# 351/351 [==============================] - 10s 28ms/step - loss: 0.3773 - accuracy: 0.8650 - val_loss: 0.6639 - val_accuracy: 0.7870
# Keras Test Macro F1-Score: 0.7980

# %% [markdown]
# ## 3. Analisis Pengaruh Hyperparameter (Menjawab Spesifikasi)

# %%
print("=== Ringkasan Hasil 16 Variasi CNN (Macro F1-Score) ===")
for i, res in evaluation_results.items():
    nl, fl, ks, pt = res['config']
    print(f"Var {i+1}: Layers={nl}, Filters={fl[-1]}, Kernel={ks[0]}, Pool={pt} --> F1-Score = {res['f1_score']:.4f}")

# Plot Grafik Training & Validation Loss
plt.figure(figsize=(20, 15))
for i in range(16):
    plt.subplot(4, 4, i+1)
    plt.plot(history_dict[i]['loss'], label='Train')
    plt.plot(history_dict[i]['val_loss'], label='Val')
    nl, fl, ks, pt = variations[i]
    plt.title(f"L={nl}, F={fl[-1]}, K={ks[0]}, P={pt}")
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
plt.tight_layout()
plt.show()
# Out:
# === Ringkasan Hasil 16 Variasi CNN (Macro F1-Score) ===
# Var 1: Layers=2, Filters=32, Kernel=(3, 3), Pool=max --> F1-Score = 0.7651
# Var 2: Layers=2, Filters=32, Kernel=(3, 3), Pool=avg --> F1-Score = 0.7473
# Var 3: Layers=2, Filters=32, Kernel=(5, 5), Pool=max --> F1-Score = 0.7639
# Var 4: Layers=2, Filters=32, Kernel=(5, 5), Pool=avg --> F1-Score = 0.7508
# Var 5: Layers=2, Filters=64, Kernel=(3, 3), Pool=max --> F1-Score = 0.7749
# Var 6: Layers=2, Filters=64, Kernel=(3, 3), Pool=avg --> F1-Score = 0.7695
# Var 7: Layers=2, Filters=64, Kernel=(5, 5), Pool=max --> F1-Score = 0.7434
# Var 8: Layers=2, Filters=64, Kernel=(5, 5), Pool=avg --> F1-Score = 0.7312
# Var 9: Layers=3, Filters=64, Kernel=(3, 3), Pool=max --> F1-Score = 0.7944
# Var 10: Layers=3, Filters=64, Kernel=(3, 3), Pool=avg --> F1-Score = 0.7728
# Var 11: Layers=3, Filters=64, Kernel=(5, 5), Pool=max --> F1-Score = 0.7689
# Var 12: Layers=3, Filters=64, Kernel=(5, 5), Pool=avg --> F1-Score = 0.7889
# Var 13: Layers=3, Filters=128, Kernel=(3, 3), Pool=max --> F1-Score = 0.8039
# Var 14: Layers=3, Filters=128, Kernel=(3, 3), Pool=avg --> F1-Score = 0.8010
# Var 15: Layers=3, Filters=128, Kernel=(5, 5), Pool=max --> F1-Score = 0.7543
# Var 16: Layers=3, Filters=128, Kernel=(5, 5), Pool=avg --> F1-Score = 0.7980

# %% [markdown]
# ## 4. Evaluasi Shared vs Non-Shared (LocallyConnected2D) di Keras

# %%
# Pilih variasi terbaik dari evaluasi F1-Score
best_idx = max(evaluation_results, key=lambda k: evaluation_results[k]['f1_score'])
nl, fl, ks, pt = variations[best_idx]
print(f"Variasi Terbaik (Shared): Var {best_idx+1} (Layers={nl}, Filters={fl}, Kernel={ks}, Pool={pt})")

keras_best = build_keras_cnn(nl, fl, ks, pt)
keras_best.load_weights(f"models/cnn_var_{best_idx}.weights.h5")

print(f"Jumlah Parameter Shared (Conv2D): {keras_best.count_params():,}")

# Arsitektur serupa dengan Non-Shared (LocallyConnected2D)
def build_keras_nonshared_cnn(num_layers, filters_list, kernel_sizes, pool_type):
    import tf_keras as legacy_keras
    inputs = legacy_keras.Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
    x = inputs
    for i in range(num_layers):
        x = legacy_keras.layers.LocallyConnected2D(filters_list[i], kernel_sizes[i], padding="valid", activation="relu", implementation=1)(x)
        if pool_type == "max":
            x = legacy_keras.layers.MaxPooling2D(pool_size=(2, 2))(x)
        else:
            x = legacy_keras.layers.AveragePooling2D(pool_size=(2, 2))(x)
    x = legacy_keras.layers.Flatten()(x)
    outputs = legacy_keras.layers.Dense(NUM_CLASSES, activation="softmax")(x)
    model = legacy_keras.Model(inputs, outputs)
    model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    return model

print("--- Melatih Arsitektur Terbaik Versi Non-Shared (LocallyConnected2D) ---")
keras_nonshared = build_keras_nonshared_cnn(nl, fl, ks, pt)
print(f"Jumlah Parameter Non-Shared (LocallyConnected2D): {keras_nonshared.count_params():,}")

optimal_batch = 16
train_ds_nonshared = make_tf_dataset(train_paths, train_labels, optimal_batch, shuffle=True)
val_ds_nonshared = make_tf_dataset(val_paths, val_labels, optimal_batch, shuffle=False)
test_ds_nonshared = make_tf_dataset(test_paths, test_labels, optimal_batch, shuffle=False)
train_steps_nonshared = (len(train_paths) + optimal_batch - 1) // optimal_batch
val_steps_nonshared = (len(val_paths) + optimal_batch - 1) // optimal_batch

history_nonshared = keras_nonshared.fit(
    train_ds_nonshared.repeat(), 
    steps_per_epoch=train_steps_nonshared, 
    validation_data=val_ds_nonshared.repeat(), 
    validation_steps=val_steps_nonshared, 
    epochs=10, 
    verbose=1,
    workers=4,
    use_multiprocessing=True
)

f1_nonshared = evaluate_f1(keras_nonshared, test_ds_nonshared)
print(f"Keras Non-Shared Test Macro F1-Score: {f1_nonshared:.4f}")

# Plot Perbandingan Loss
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history_dict[best_idx]['loss'], label='Shared Train')
plt.plot(history_dict[best_idx]['val_loss'], label='Shared Val')
plt.title('Loss Shared (Conv2D)')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history_nonshared.history['loss'], label='Non-Shared Train')
plt.plot(history_nonshared.history['val_loss'], label='Non-Shared Val')
plt.title('Loss Non-Shared (LocallyConnected)')
plt.legend()
plt.show()
# Out:
# WARNING:absl:Skipping variable loading for optimizer 'Adam', because it has 1 variables whereas the saved optimizer has 17 variables.
# Variasi Terbaik (Shared): Var 13 (Layers=3, Filters=[32, 64, 128], Kernel=[(3, 3), (3, 3), (3, 3)], Pool=max)
# Jumlah Parameter Shared (Conv2D): 142,406
# --- Melatih Arsitektur Terbaik Versi Non-Shared (LocallyConnected2D) ---
# Jumlah Parameter Non-Shared (LocallyConnected2D): 29,662,278
# Epoch 1/10
# 702/702 [==============================] - 211s 186ms/step - loss: 1.3688 - accuracy: 0.4562 - val_loss: 1.3022 - val_accuracy: 0.4653
# Epoch 2/10
# 702/702 [==============================] - 63s 89ms/step - loss: 1.1744 - accuracy: 0.5498 - val_loss: 1.1447 - val_accuracy: 0.5465
# Epoch 3/10
# 702/702 [==============================] - 62s 89ms/step - loss: 1.1083 - accuracy: 0.5768 - val_loss: 1.0998 - val_accuracy: 0.5732
# Epoch 4/10
# 702/702 [==============================] - 62s 88ms/step - loss: 1.0396 - accuracy: 0.6103 - val_loss: 1.0780 - val_accuracy: 0.5818
# Epoch 5/10
# 702/702 [==============================] - 61s 87ms/step - loss: 0.9786 - accuracy: 0.6276 - val_loss: 1.0215 - val_accuracy: 0.6170
# Epoch 6/10
# 702/702 [==============================] - 61s 87ms/step - loss: 0.9306 - accuracy: 0.6542 - val_loss: 1.0510 - val_accuracy: 0.5974
# Epoch 7/10
# 702/702 [==============================] - 58s 83ms/step - loss: 0.8933 - accuracy: 0.6658 - val_loss: 0.9461 - val_accuracy: 0.6398
# Epoch 8/10
# 702/702 [==============================] - 58s 82ms/step - loss: 0.8621 - accuracy: 0.6732 - val_loss: 0.9389 - val_accuracy: 0.6484
# Epoch 9/10
# 702/702 [==============================] - 59s 84ms/step - loss: 0.8254 - accuracy: 0.6933 - val_loss: 0.9296 - val_accuracy: 0.6512
# Epoch 10/10
# 702/702 [==============================] - 59s 84ms/step - loss: 0.7885 - accuracy: 0.7087 - val_loss: 0.9408 - val_accuracy: 0.6380
# Keras Non-Shared Test Macro F1-Score: 0.6507

# %% [markdown]
# ## 5. Evaluasi From Scratch: Keras vs Scratch pada Test Split

# %%
# Model Scratch
def get_scratch_model(keras_model, conv_kind="conv", force_valid_padding=False):
    blocks = []
    for i in range(nl):
        pad_type = "valid" if force_valid_padding else "same"
        blocks.append(ConvBlockSpec(filters=fl[i], kernel_size=ks[i], padding=pad_type, pool_size=(2,2), use_pool=True))
    
    scratch_model = CNNClassifier(input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3), num_classes=NUM_CLASSES, 
                                  conv_blocks=blocks, conv_kind=conv_kind, pool_kind=pt, head_kind="flatten")
    
    # Transfer Weights (Keras to Scratch)
    conv_idx = 0
    for layer in keras_model.layers:
        if isinstance(layer, layers.Conv2D) or isinstance(layer, layers.LocallyConnected2D):
            w, b = layer.get_weights()
            scratch_model.set_conv_weights(conv_idx, w, b)
            conv_idx += 1
        elif isinstance(layer, layers.Dense):
            w, b = layer.get_weights()
            scratch_model.set_output_weights(w, b)
    return scratch_model

scratch_shared = get_scratch_model(keras_best, conv_kind="conv")
scratch_nonshared = get_scratch_model(keras_best, conv_kind="locally")

print("=== Perbandingan Keras vs From Scratch pada Test Data ===")
# Evaluasi pada semua batch di data test
y_true_all = []
y_pred_k_shared = []
y_pred_s_shared = []
y_pred_s_nonshared = []

t_keras_total = 0
t_shared_total = 0
t_nonshared_total = 0

batch_count = 0
for X_batch, y_batch in test_ds:
    X_np = X_batch.numpy()
    y_true_all.extend(y_batch.numpy())
    
    # 1. Prediksi Keras
    t0 = time.time()
    keras_preds = keras_best.predict(X_np, verbose=0)
    t_keras_total += time.time() - t0
    y_pred_k_shared.extend(np.argmax(keras_preds, axis=1))
    
    # 2. Prediksi Scratch Shared
    t0 = time.time()
    scratch_preds_shared = scratch_shared.predict(X_np, use_gpu=True)
    t_shared_total += time.time() - t0
    y_pred_s_shared.extend(np.argmax(scratch_preds_shared, axis=1))

    # 3. Prediksi Scratch Non-Shared
    t0 = time.time()
    scratch_preds_nonshared = scratch_nonshared.predict(X_np, use_gpu=False)
    t_nonshared_total += time.time() - t0
    y_pred_s_nonshared.extend(np.argmax(scratch_preds_nonshared, axis=1))
    
    batch_count += 1
    if batch_count % 10 == 0:
        print(f"Processed {batch_count} batches...")

print("--- Hasil Akhir Prediksi Test Split ---")
print(f"Keras Shared Macro F1     : {f1_score(y_true_all, y_pred_k_shared, average='macro'):.4f} (Waktu: {t_keras_total:.2f}s)")
print(f"Scratch Shared Macro F1   : {f1_score(y_true_all, y_pred_s_shared, average='macro'):.4f} (Waktu: {t_shared_total:.2f}s)")
print(f"Scratch NonShared Macro F1: {f1_score(y_true_all, y_pred_s_nonshared, average='macro'):.4f} (Waktu: {t_nonshared_total:.2f}s)")
# Out:
# === Perbandingan Keras vs From Scratch pada Test Data ===
# Processed 10 batches...
# Processed 20 batches...
# Processed 30 batches...
# Processed 40 batches...
# Processed 50 batches...
# Processed 60 batches...
# Processed 70 batches...
# Processed 80 batches...
# Processed 90 batches...
# --- Hasil Akhir Prediksi Test Split ---
# Keras Shared Macro F1     : 0.8039 (Waktu: 9.01s)
# Scratch Shared Macro F1   : 0.4371 (Waktu: 1.39s)
# Scratch NonShared Macro F1: 0.4371 (Waktu: 6.18s)

# %% [markdown]
# ## 6. Visualisasi Fitur (Grad-CAM Bonus)

# %%
# Penggunaan Grad-CAM pada model scratch shared
X_test, _ = next(iter(test_ds.take(1)))
img_sample = X_test.numpy()[0]

heatmap, target_cls, probs = scratch_shared.grad_cam(img_sample)
overlay, resized, _, _ = scratch_shared.grad_cam_overlay(img_sample)

plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.title("Original Image")
plt.imshow(img_sample)
plt.axis("off")

plt.subplot(1, 3, 2)
plt.title(f"Heatmap (Class: {target_cls})")
plt.imshow(resized, cmap="jet")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.title("Overlay")
plt.imshow(overlay)
plt.axis("off")
plt.show()
